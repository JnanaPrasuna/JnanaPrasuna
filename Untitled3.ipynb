# %% [markdown]
# <a href="https://colab.research.google.com/github/JnanaPrasuna/JnanaPrasuna/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Basic Line Plot

# %% [markdown]
# Plot a simple line graph of 𝑦 = 𝑥 2 for 𝑥 values ranging from -10 to 10. Label the x-axis as "X Values" and the y-axis as "Squared Values." Add a title to the graph.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(-10,11)
y=x**2
plt.plot(x,y)
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Simple Line Plot")
plt.show()

# %% [markdown]
# Bar Plot

# %% [markdown]
# Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi''Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88]. Add labels to the x-axis and y-axis and give the chart a title.

# %%
students=['Sai','Vamsi','Divij','Sritan','Sita']
marks=[85,90,78,92,88]
plt.bar(students,marks)
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Marks scored by 5 Students")
plt.show()

# %% [markdown]
# Scatter plot

# %% [markdown]
# Generate two lists of 20 random integers each (for x and y coordinates). Create a scatter plot with these values, and customize it by adding color, size, and labels to the points.

# %%
x=[np.random.randint(1,100) for i in range(20)]
y=[np.random.randint(1,100) for i in range(20)]
plt.scatter(x,y,c='purple')
plt.xlabel("X Coordinates")
plt.ylabel("Y Coordinates")
plt.title("Scatter Plot of Random Points")
plt.show()

# %% [markdown]
# Histogram

# %% [markdown]
# Simulate 100 random values from a normal distribution using np.random.randn() and plot a histogram. Customize the number of bins and add a grid to the plot.

# %%
data=np.random.randn(100)
plt.hist(data,bins=10)
plt.grid(True)
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram of Random Values")
plt.show()

# %% [markdown]
# Pie Chart

# %% [markdown]
# Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E'] with values [20, 30, 25, 15, 10]. Display the percentage values on the chart and use a color palette for differentiation.

# %%
categories=['A','B','C','D','E']
values=[20,30,25,15,10]
colors=['red','green','blue','yellow','orange']
plt.pie(values,labels=categories,colors=colors,autopct='%1.1f%%')
plt.title("Percentage Distribution of Categories")
plt.show()

# %% [markdown]
# Box Plot (Seaborn)

# %% [markdown]
# Create a box plot to visualize the distribution of the marks scored by students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73]. Highlight the median and any outliers.

# %%
import seaborn as sns
marks=[78,85,92,88,76,95,89,84,91,73]
sns.boxplot(x=marks)
plt.title("Box Plot of Marks")
plt.show()

# %% [markdown]
# Heatmap (Seaborn)

# %% [markdown]
# Create a 5x5 matrix with random integers between 1 and 10 using np.random.randint() and visualize it as a heatmap using Seaborn. Add a color bar and annotate the heatmap with the values.

# %%
matrix=np.random.randint(1,11,size=(5,5))
sns.heatmap(matrix,annot=True,cmap='coolwarm',cbar=True)
plt.title("Heatmap of Random Integers")
plt.show()

# %% [markdown]
# Comparison of Matplotlib and Seaborn

# %% [markdown]
# Generate a pair of plots (bar charts or line plots) using the same data in both Matplotlib and Seaborn. Highlight the differences in the code, syntax, and aesthetics of the two libraries.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns # Import seaborn before using it


students = ['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita']
marks = [85, 90, 78, 92, 88]
plt.bar(students, marks)
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Marks scored by 5 Students using matplotlib")
plt.show()

data = pd.DataFrame({'Student': students, 'Marks': marks})
sns.barplot(x='Student', y='Marks', data=data) # Now sns is defined
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Marks scored by 5 Students using seaborn")
plt.show()

# %% [markdown]
# Pair Plot (Seaborn)

# %% [markdown]
# Manually create a small dataset with columns such as 'Age', 'Height', 'Weight' for 10 individuals and visualize the relationships using a pair plot.

# %%
data={
    'Age':[25,30,22,35,28,32,27,29,31,26],
    'Height':[165,170,160,175,168,172,163,169,171,167],
    'Weight':[65,70,60,75,68,72,68,71,73,67]
}
df=pd.DataFrame(data)
sns.pairplot(df)
plt.show()

# %% [markdown]
# Save and Style Plots

# %% [markdown]
# Plot any graph of your choice and save it in both .png and .pdf formats.

# %%
x=np.linspace(-10,10,100)
y=x**2
plt.plot(x,y)
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Parabola")
plt.savefig("paarbola_plot.png")
plt.savefig("parabola_plot.pdf")
plt.show()

# %% [markdown]
# Apply at least one built-in style (e.g., 'ggplot' or 'seaborn-darkgrid') and explain how the style impacts the visualization.

# %%
plt.style.use('ggplot')
x=np.linspace(-10,10,100)
y=x**2
plt.plot(x,y)
plt.xlabel("X Values")
plt.ylabel("Squared Values")
plt.title("Parabola")
plt.savefig("paarbola_plot_ggplot.png")
